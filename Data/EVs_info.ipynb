# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Raw_files/EVs_1995-2020.csv")

# %%
data.head()
# Out:
#       Category             Model  Model Year Manufacturer  \
# 0  Sedan/Wagon               A8L        2020         Audi
# 1          SUV            e-tron        2020         Audi
# 2          SUV  e-tron Sportback        2020         Audi
# 3  Sedan/Wagon                Q5        2020         Audi
# 4  Sedan/Wagon              530e        2020          BMW
#
#                       Fuel  All Electric Range  Alternative Fuel Economy City  \
# 0  Plug-in Hybrid Electric                17.0                            NaN
# 1                 Electric               222.0                           78.0
# 2                 Electric               218.0                           76.0
# 3  Plug-in Hybrid Electric                20.0                            NaN
# 4  Plug-in Hybrid Electric                21.0                            NaN
#
#    Alternative Fuel Economy Highway  Alternative Fuel Economy Combined  \
# 0                               NaN                               54.0
# ...

# %%
data = data.rename(columns={"Alternative Fuel Economy City": "Alt Fuel Economy City",
                            "Alternative Fuel Economy Highway": "Alt Fuel Economy Highway",
                            "Alternative Fuel Economy Combined": "Alt Fuel Economy Combined",
                            "Conventional Fuel Economy City": "Conv Fuel Economy City",
                            "Conventional Fuel Economy Highway": "Conv Fuel Economy Highway",
                            "Conventional Fuel Economy Combined": "Conv Fuel Economy Combined",
                            "Category": "Vehicle Category",
                            "Fuel": "Fuel Type",
                            "Model": "Model Name"})

# %%
ev1 = data.drop(columns=['Transmission Make', 'Number of Passengers', 'Heavy-Duty Power System', 'Notes'])

# %%
ev1
# Out:
#     Vehicle Category            Model Name  Model Year       Manufacturer  \
# 0        Sedan/Wagon                   A8L        2020               Audi
# 1                SUV                e-tron        2020               Audi
# 2                SUV      e-tron Sportback        2020               Audi
# 3        Sedan/Wagon                    Q5        2020               Audi
# 4        Sedan/Wagon                  530e        2020                BMW
# ..               ...                   ...         ...                ...
# 260              SUV  RAV4-EV PbA (Fleets)        1998             Toyota
# 261            Truck    Chevrolet S-10 PbA        1997          Chevrolet
# 262            Truck             Ranger EV        1997               Ford
# 263      Sedan/Wagon         EV1-Lead Acid        1997  General Motors EV
# 264              Van       Plymouth TE Van        1995              Dodge
#
#                    Fuel Type  All Electric Range  Alt Fuel Economy City  \
# ...

# %%
ev1.dtypes
# Out:
# Vehicle Category               object
# Model Name                     object
# Model Year                      int64
# Manufacturer                   object
# Fuel Type                      object
# All Electric Range            float64
# Alt Fuel Economy City         float64
# Alt Fuel Economy Highway      float64
# Alt Fuel Economy Combined     float64
# Conv Fuel Economy City        float64
# Conv Fuel Economy Highway     float64
# Conv Fuel Economy Combined    float64
# Transmission Type              object
# Engine Type                    object
# Engine Size                    object
# Engine Cylinder Count         float64
# dtype: object

# %%
ev1.to_csv('Clean_files/EVs_data.csv', index=False)
